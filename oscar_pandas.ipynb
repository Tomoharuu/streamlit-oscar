# %%
import pandas as pd
df = pd.read_csv("full_data.csv", encoding="utf-8", sep='\t')
df.columns
# Out:
# Index(['Ceremony', 'Year', 'Class', 'CanonicalCategory', 'Category', 'NomId',
#        'Film', 'FilmId', 'Name', 'Nominees', 'NomineeIds', 'Winner', 'Detail',
#        'Note', 'Citation', 'MultifilmNomination'],
#       dtype='object')

# %%
df
# Out:
#        Ceremony     Year    Class  \
# 0             1  1927/28   Acting
# 1             1  1927/28   Acting
# 2             1  1927/28   Acting
# 3             1  1927/28   Acting
# 4             1  1927/28   Acting
# ...         ...      ...      ...
# 12009        97     2024  SciTech
# 12010        97     2024  SciTech
# 12011        97     2024  SciTech
# 12012        97     2024  SciTech
# 12013        97     2024  SciTech
#
#                                        CanonicalCategory  \
# 0                                ACTOR IN A LEADING ROLE
# 1                                ACTOR IN A LEADING ROLE
# 2                                ACTOR IN A LEADING ROLE
# 3                                ACTOR IN A LEADING ROLE
# 4                              ACTRESS IN A LEADING ROLE
# ...                                                  ...
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12010  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Ceremony     Year    Class  \
# 0             1  1927/28   Acting
# 1             1  1927/28   Acting
# 2             1  1927/28   Acting
# 3             1  1927/28   Acting
# 4             1  1927/28   Acting
# ...         ...      ...      ...
# 12009        97     2024  SciTech
# 12010        97     2024  SciTech
# 12011        97     2024  SciTech
# 12012        97     2024  SciTech
# 12013        97     2024  SciTech
#
#                                        CanonicalCategory  \
# 0                                ACTOR IN A LEADING ROLE
# 1                                ACTOR IN A LEADING ROLE
# 2                                ACTOR IN A LEADING ROLE
# 3                                ACTOR IN A LEADING ROLE
# 4                              ACTRESS IN A LEADING ROLE
# ...                                                  ...
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# ...

# %%
df2 = pd.read_csv("the_oscar_award.csv")
df2.columns
# Out:
# Index(['year_film', 'year_ceremony', 'ceremony', 'category', 'canon_category',
#        'name', 'film', 'winner'],
#       dtype='object')

# %%
df2
# Out:
#        year_film  year_ceremony  ceremony                           category  \
# 0           1927           1928         1                              ACTOR
# 1           1927           1928         1                              ACTOR
# 2           1927           1928         1                              ACTOR
# 3           1927           1928         1                              ACTOR
# 4           1927           1928         1                            ACTRESS
# ...          ...            ...       ...                                ...
# 11105       2024           2025        97      WRITING (Original Screenplay)
# 11106       2024           2025        97   JEAN HERSHOLT HUMANITARIAN AWARD
# 11107       2024           2025        97                     HONORARY AWARD
# 11108       2024           2025        97                     HONORARY AWARD
# 11109       2024           2025        97  IRVING G. THALBERG MEMORIAL AWARD
#
# ...

# %%
df.dropna(axis=0, subset=["Name", "Film"])
# Out:
#        Ceremony     Year    Class              CanonicalCategory  \
# 0             1  1927/28   Acting        ACTOR IN A LEADING ROLE
# 1             1  1927/28   Acting        ACTOR IN A LEADING ROLE
# 2             1  1927/28   Acting        ACTOR IN A LEADING ROLE
# 3             1  1927/28   Acting        ACTOR IN A LEADING ROLE
# 4             1  1927/28   Acting      ACTRESS IN A LEADING ROLE
# ...         ...      ...      ...                            ...
# 11991        97     2024  Writing  WRITING (Original Screenplay)
# 11992        97     2024  Writing  WRITING (Original Screenplay)
# 11993        97     2024  Writing  WRITING (Original Screenplay)
# 11994        97     2024  Writing  WRITING (Original Screenplay)
# 11995        97     2024  Writing  WRITING (Original Screenplay)
#
#                             Category          NomId                    Film  \
# 0                              ACTOR      an0051251               The Noose
# ...

# %%
df2.dropna(axis=0, subset=["name", "film"])
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 0           1927           1928         1                          ACTOR
# 1           1927           1928         1                          ACTOR
# 2           1927           1928         1                          ACTOR
# 3           1927           1928         1                          ACTOR
# 4           1927           1928         1                        ACTRESS
# ...          ...            ...       ...                            ...
# 11101       2024           2025        97  WRITING (Original Screenplay)
# 11102       2024           2025        97  WRITING (Original Screenplay)
# 11103       2024           2025        97  WRITING (Original Screenplay)
# 11104       2024           2025        97  WRITING (Original Screenplay)
# 11105       2024           2025        97  WRITING (Original Screenplay)
#
#                       canon_category                                   name  \
# ...

# %%
df[["Year", "Category", "Film", "Note"]].dropna(subset=["Note"])
# Out:
#           Year                                           Category     Film  \
# 16     1927/28                                     CINEMATOGRAPHY  Sunrise
# 22     1927/28                                ENGINEERING EFFECTS      NaN
# 24     1927/28                                ENGINEERING EFFECTS      NaN
# 37     1927/28                            WRITING (Title Writing)      NaN
# 38     1927/28                            WRITING (Title Writing)      NaN
# ...        ...                                                ...      ...
# 12009     2024  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...      NaN
# 12010     2024  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...      NaN
# 12011     2024  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...      NaN
# 12012     2024  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...      NaN
# 12013     2024  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...      NaN
#
#                                                     Note
# ...

# %%
df2[["year_ceremony", "category", "film"]]
# Out:
#        year_ceremony                           category  \
# 0               1928                              ACTOR
# 1               1928                              ACTOR
# 2               1928                              ACTOR
# 3               1928                              ACTOR
# 4               1928                            ACTRESS
# ...              ...                                ...
# 11105           2025      WRITING (Original Screenplay)
# 11106           2025   JEAN HERSHOLT HUMANITARIAN AWARD
# 11107           2025                     HONORARY AWARD
# 11108           2025                     HONORARY AWARD
# 11109           2025  IRVING G. THALBERG MEMORIAL AWARD
#
#                          film
# 0                   The Noose
# 1      The Patent Leather Kid
# 2            The Last Command
# 3        The Way of All Flesh
# 4             A Ship Comes In
# ...                       ...
# 11105           The Substance
# 11106                     NaN
# ...

# %%
df2[(df2["category"] == "SPECIAL AWARD")].describe()
# Out:
#          year_film  year_ceremony   ceremony
# count    56.000000      56.000000  56.000000
# mean   1942.910714    1943.910714  15.964286
# std      11.419723      11.419723  11.352155
# min    1927.000000    1928.000000   1.000000
# 25%    1938.000000    1939.000000  11.000000
# 50%    1941.500000    1942.500000  14.500000
# 75%    1946.250000    1947.250000  19.250000
# max    2017.000000    2018.000000  90.000000

# %%
df2
# Out:
#        year_film  year_ceremony  ceremony                           category  \
# 0           1927           1928         1                              ACTOR
# 1           1927           1928         1                              ACTOR
# 2           1927           1928         1                              ACTOR
# 3           1927           1928         1                              ACTOR
# 4           1927           1928         1                            ACTRESS
# ...          ...            ...       ...                                ...
# 11105       2024           2025        97      WRITING (Original Screenplay)
# 11106       2024           2025        97   JEAN HERSHOLT HUMANITARIAN AWARD
# 11107       2024           2025        97                     HONORARY AWARD
# 11108       2024           2025        97                     HONORARY AWARD
# 11109       2024           2025        97  IRVING G. THALBERG MEMORIAL AWARD
#
# ...
